# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\sande\anaconda3\lib\site-packages (0.0.284)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.21 in c:\users\sande\anaconda3\lib\site-packages (from langchain) (0.0.92)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in c:\users\sande\anaconda3\lib\site-packages (from langchain) (0.5.14)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\sande\anaconda3\lib\site-packages (from langchain) (4.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\sande\anaconda3\lib\site-packages (from langchain) (3.11.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\sande\anaconda3\lib\site-packages (from langchain) (2.0.36)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\sande\anaconda3\lib\site-packages (from langchain) (8.2.3)
# Requirement already satisfied: numpy<2,>=1 in c:\users\sande\anaconda3\lib\site-packages (from langchain) (1.23.5)
# Requirement already satisfied: requests<3,>=2 in c:\users\sande\anaconda3\lib\site-packages (from langchain) (2.31.0)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in c:\users\sande\anaconda3\lib\site-packages (from langchain) (2.10.1)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\sande\anaconda3\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\sande\anaconda3\lib\site-packages (from langchain) (2.9.2)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\sande\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sande\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\sande\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sande\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (21.4.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\sande\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.17.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sande\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (5.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\sande\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\sande\anaconda3\lib\site-packages (from async-timeout<5.0.0,>=4.0.0->langchain) (4.8.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\sande\anaconda3\lib\site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\sande\anaconda3\lib\site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (3.23.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\sande\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sande\anaconda3\lib\site-packages (from packaging>=17.0->marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (3.0.4)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\sande\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain) (2.23.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sande\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sande\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sande\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2021.10.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sande\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sande\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sande\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (1.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\sande\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (0.4.3)

# %%
# !pip install langchain-groq
# Out:
# Collecting langchain-groq
#   Downloading langchain_groq-0.2.1-py3-none-any.whl (14 kB)
# Collecting groq<1,>=0.4.1
#   Downloading groq-0.12.0-py3-none-any.whl (108 kB)
# Collecting langchain-core<0.4.0,>=0.3.15
#   Using cached langchain_core-0.3.19-py3-none-any.whl (409 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\sande\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\sande\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (2.9.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\sande\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (4.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sande\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (0.23.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\sande\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (3.5.0)
# Requirement already satisfied: sniffio in c:\users\sande\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\sande\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (3.3)
# Requirement already satisfied: certifi in c:\users\sande\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (2021.10.8)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in c:\users\sande\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (1.5.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in c:\users\sande\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (0.16.3)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sande\anaconda3\lib\site-packages (from httpcore<0.17.0,>=0.15.0->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (0.14.0)
# Collecting langsmith<0.2.0,>=0.1.125
#   Using cached langsmith-0.1.143-py3-none-any.whl (306 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sande\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-groq) (8.2.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\sande\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-groq) (6.0)
# Collecting jsonpatch<2.0,>=1.33
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting packaging<25,>=23.2
#   Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Collecting jsonpointer>=1.9
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: requests<3,>=2 in c:\users\sande\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-groq) (2.31.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\sande\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-groq) (3.9.14)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\sande\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-groq) (1.0.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\sande\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (2.23.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sande\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sande\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-groq) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sande\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-groq) (1.26.9)
# Installing collected packages: jsonpointer, packaging, langsmith, jsonpatch, langchain-core, groq, langchain-groq
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.0.92
#     Uninstalling langsmith-0.0.92:
#       Successfully uninstalled langsmith-0.0.92
# Successfully installed groq-0.12.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-core-0.3.19 langchain-groq-0.2.1 langsmith-0.1.143 packaging-24.2
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.0.284 requires langsmith<0.1.0,>=0.0.21, but you have langsmith 0.1.143 which is incompatible.
# jupyter-server 1.13.5 requires pywinpty<2; os_name == "nt", but you have pywinpty 2.0.2 which is incompatible.
# huggingface-hub 0.20.3 requires fsspec>=2023.5.0, but you have fsspec 0.8.7 which is incompatible.
# distributed 2022.2.1 requires dask==2022.02.1, but you have dask 2022.3.0 which is incompatible.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
        model_name="llama-3.1-70b-versatile",
        temperature=0,
        groq_api_key="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"
)

response= llm.invoke("The First prime minister of India was.....")

# %%
response
# Out:
# AIMessage(content='Jawaharlal Nehru.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 43, 'total_tokens': 51, 'completion_time': 0.032, 'prompt_time': 0.007464998, 'queue_time': 0.007047492, 'total_time': 0.039464998}, 'model_name': 'llama-3.1-70b-versatile', 'system_fingerprint': 'fp_9260b4bb2e', 'finish_reason': 'stop', 'logprobs': None}, id='run-1baad1f2-0275-4cec-9c4e-99edc2364ae6-0', usage_metadata={'input_tokens': 43, 'output_tokens': 8, 'total_tokens': 51})

# %%
# !pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-0.5.18-py3-none-any.whl (615 kB)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\sande\anaconda3\lib\site-packages (from chromadb) (6.0)
# Collecting tokenizers>=0.13.2
#   Downloading tokenizers-0.20.3-cp39-none-win_amd64.whl (2.4 MB)
# Collecting posthog>=2.4.0
#   Downloading posthog-3.7.0-py2.py3-none-any.whl (54 kB)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\sande\anaconda3\lib\site-packages (from chromadb) (1.60.0)
# Requirement already satisfied: importlib-resources in c:\users\sande\anaconda3\lib\site-packages (from chromadb) (6.0.1)
# Collecting chroma-hnswlib==0.7.6
#   Downloading chroma_hnswlib-0.7.6-cp39-cp39-win_amd64.whl (151 kB)
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.19.2-cp39-cp39-win_amd64.whl (11.1 MB)
# Requirement already satisfied: typer>=0.9.0 in c:\users\sande\anaconda3\lib\site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\sande\anaconda3\lib\site-packages (from chromadb) (2.9.2)
# Collecting build>=1.0.3
#   Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Collecting overrides>=7.3.1
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.28.1-py3-none-any.whl (64 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\sande\anaconda3\lib\site-packages (from chromadb) (4.8.0)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0
#   Downloading opentelemetry_instrumentation_fastapi-0.49b1-py3-none-any.whl (12 kB)
# Requirement already satisfied: rich>=10.11.0 in c:\users\sande\anaconda3\lib\site-packages (from chromadb) (13.7.0)
# Collecting httpx>=0.27.0
#   Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\sande\anaconda3\lib\site-packages (from chromadb) (1.23.5)
# Collecting kubernetes>=28.1.0
#   Downloading kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
# Collecting pypika>=0.48.9
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting bcrypt>=4.0.1
#   Downloading bcrypt-4.2.0-cp39-abi3-win_amd64.whl (151 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\sande\anaconda3\lib\site-packages (from chromadb) (3.9.14)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\sande\anaconda3\lib\site-packages (from chromadb) (0.109.2)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\users\sande\anaconda3\lib\site-packages (from chromadb) (0.27.1)
# Collecting tqdm>=4.65.0
#   Downloading tqdm-4.67.0-py3-none-any.whl (78 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.28.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\sande\anaconda3\lib\site-packages (from chromadb) (8.2.3)
# Collecting mmh3>=4.0.1
#   Downloading mmh3-5.0.1-cp39-cp39-win_amd64.whl (39 kB)
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.28.1-py3-none-any.whl (118 kB)
# Requirement already satisfied: colorama in c:\users\sande\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\sande\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.2)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\sande\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (6.8.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\sande\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (24.2)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in c:\users\sande\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.36.3)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
# Requirement already satisfied: idna in c:\users\sande\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.3)
# Requirement already satisfied: sniffio in c:\users\sande\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.2.0)
# Requirement already satisfied: anyio in c:\users\sande\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.5.0)
# Requirement already satisfied: certifi in c:\users\sande\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2021.10.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sande\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\sande\anaconda3\lib\site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb) (3.7.0)
# Requirement already satisfied: requests-oauthlib in c:\users\sande\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Collecting durationpy>=0.7
#   Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\sande\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.9)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\sande\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\sande\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.27.0)
# Requirement already satisfied: requests in c:\users\sande\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\sande\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\sande\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\sande\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sande\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sande\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sande\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: protobuf in c:\users\sande\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.3)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Requirement already satisfied: flatbuffers in c:\users\sande\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: sympy in c:\users\sande\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.10.1)
# Collecting deprecated>=1.2.6
#   Downloading Deprecated-1.2.15-py2.py3-none-any.whl (9.9 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\sande\anaconda3\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.2.0->chromadb) (1.12.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\sande\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.62.0)
# Collecting opentelemetry-proto==1.28.1
#   Downloading opentelemetry_proto-1.28.1-py3-none-any.whl (55 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.28.1
#   Downloading opentelemetry_exporter_otlp_proto_common-1.28.1-py3-none-any.whl (18 kB)
# Collecting grpcio>=1.58.0
#   Downloading grpcio-1.68.0-cp39-cp39-win_amd64.whl (4.4 MB)
# Collecting protobuf
#   Downloading protobuf-5.28.3-cp39-cp39-win_amd64.whl (431 kB)
# Collecting googleapis-common-protos~=1.52
#   Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl (221 kB)
# Collecting opentelemetry-util-http==0.49b1
#   Downloading opentelemetry_util_http-0.49b1-py3-none-any.whl (6.9 kB)
# Collecting opentelemetry-instrumentation-asgi==0.49b1
#   Downloading opentelemetry_instrumentation_asgi-0.49b1-py3-none-any.whl (16 kB)
# Collecting opentelemetry-semantic-conventions==0.49b1
#   Downloading opentelemetry_semantic_conventions-0.49b1-py3-none-any.whl (159 kB)
# Collecting opentelemetry-instrumentation==0.49b1
#   Downloading opentelemetry_instrumentation-0.49b1-py3-none-any.whl (30 kB)
# Collecting asgiref~=3.0
#   Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\sande\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\sande\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.23.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sande\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sande\anaconda3\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (2.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sande\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sande\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sande\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\sande\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.20.3)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Requirement already satisfied: filelock in c:\users\sande\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\sande\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (7.1.2)
# Requirement already satisfied: websockets>=10.4 in c:\users\sande\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (11.0.3)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\sande\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-0.24.0-cp39-none-win_amd64.whl (277 kB)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.5.1 requires pydantic<2,>=1.8.1, but you have pydantic 2.9.2 which is incompatible.
# tensorflow-intel 2.15.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.28.3 which is incompatible.
# python-telegram-bot 20.2 requires httpx~=0.23.3, but you have httpx 0.27.2 which is incompatible.
# proto-plus 1.23.0 requires protobuf<5.0.0dev,>=3.19.0, but you have protobuf 5.28.3 which is incompatible.
# langchain 0.0.284 requires langsmith<0.1.0,>=0.0.21, but you have langsmith 0.1.143 which is incompatible.
# google-api-core 2.15.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5, but you have protobuf 5.28.3 which is incompatible.
# google-ai-generativelanguage 0.4.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.3 which is incompatible.
# dataprep 0.4.5 requires flask<3,>=2, but you have flask 1.1.2 which is incompatible.
# dataprep 0.4.5 requires jinja2<3.1,>=3.0, but you have jinja2 3.1.3 which is incompatible.
# dataprep 0.4.5 requires pydantic<2.0,>=1.6, but you have pydantic 2.9.2 which is incompatible.
# dataprep 0.4.5 requires sqlalchemy==1.3.24, but you have sqlalchemy 2.0.36 which is incompatible.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sande\anaconda3\lib\site-packages)
# Collecting httptools>=0.5.0
#   Downloading httptools-0.6.4-cp39-cp39-win_amd64.whl (89 kB)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting pyreadline3
#   Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Requirement already satisfied: mpmath>=0.19 in c:\users\sande\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (PEP 517): started
#   Building wheel for pypika (PEP 517): finished with status 'done'
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53836 sha256=4762b942c5c2ce1b9005519521ee0a7004d3dce0dc7d17a01877562468c07dbf
#   Stored in directory: c:\users\sande\appdata\local\pip\cache\wheels\f7\02\64\d541eac67ec459309d1fb19e727f58ecf7ffb4a8bf42d4cfe5
# Successfully built pypika
# Installing collected packages: deprecated, opentelemetry-api, pyreadline3, protobuf, opentelemetry-semantic-conventions, tqdm, opentelemetry-util-http, opentelemetry-proto, opentelemetry-instrumentation, humanfriendly, fsspec, asgiref, watchfiles, pyproject-hooks, opentelemetry-sdk, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-common, monotonic, httptools, httpcore, grpcio, googleapis-common-protos, durationpy, coloredlogs, backoff, tokenizers, pypika, posthog, overrides, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, onnxruntime, mmh3, kubernetes, httpx, chroma-hnswlib, build, bcrypt, chromadb
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Uninstalling protobuf-4.25.3:
#       Successfully uninstalled protobuf-4.25.3
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.0
#     Uninstalling tqdm-4.64.0:
#       Successfully uninstalled tqdm-4.64.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 0.8.7
#     Uninstalling fsspec-0.8.7:
#       Successfully uninstalled fsspec-0.8.7
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 0.16.3
#     Uninstalling httpcore-0.16.3:
#       Successfully uninstalled httpcore-0.16.3
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.60.0
#     Uninstalling grpcio-1.60.0:
#       Successfully uninstalled grpcio-1.60.0
#   Attempting uninstall: googleapis-common-protos
#     Found existing installation: googleapis-common-protos 1.62.0
#     Uninstalling googleapis-common-protos-1.62.0:
#       Successfully uninstalled googleapis-common-protos-1.62.0
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.23.3
#     Uninstalling httpx-0.23.3:
#       Successfully uninstalled httpx-0.23.3
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 3.2.0
#     Uninstalling bcrypt-3.2.0:
#       Successfully uninstalled bcrypt-3.2.0
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.2.0 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-0.5.18 coloredlogs-15.0.1 deprecated-1.2.15 durationpy-0.9 fsspec-2024.10.0 googleapis-common-protos-1.66.0 grpcio-1.68.0 httpcore-1.0.7 httptools-0.6.4 httpx-0.27.2 humanfriendly-10.0 kubernetes-31.0.0 mmh3-5.0.1 monotonic-1.6 onnxruntime-1.19.2 opentelemetry-api-1.28.1 opentelemetry-exporter-otlp-proto-common-1.28.1 opentelemetry-exporter-otlp-proto-grpc-1.28.1 opentelemetry-instrumentation-0.49b1 opentelemetry-instrumentation-asgi-0.49b1 opentelemetry-instrumentation-fastapi-0.49b1 opentelemetry-proto-1.28.1 opentelemetry-sdk-1.28.1 opentelemetry-semantic-conventions-0.49b1 opentelemetry-util-http-0.49b1 overrides-7.7.0 posthog-3.7.0 protobuf-5.28.3 pypika-0.48.9 pyproject-hooks-1.2.0 pyreadline3-3.5.4 tokenizers-0.20.3 tqdm-4.67.0 watchfiles-0.24.0
